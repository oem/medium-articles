# %% [markdown]
# # Exploring data in julia

# %% [markdown]
# ## Previously
#
# Last time, we build a [webcrawler]() that would crawl the [hamburg.de](https://www.hamburg.de/corona-zahlen/) website for the current covid-19 numbers in hamburg.
#
# I went ahead and wrote a [small package, Hamburg.jl](https://github.com/oem/Hamburg.jl) that provides those numbers for all recorded days, not just a current snapshot.
#
# Let's quickly recreate the borough plot we did last time, this time with the help of the package (there won't be much webscraping this time).

# %%
using Hamburg
using Dates
using DataFrames

# %% [markdown]
# We are going to use [Gadfly.jl](http://gadflyjl.org/stable/) again, the plots look great.

# %%
using Gadfly
Gadfly.set_default_plot_size(900px, 300px)

# %%
boroughs = dataset("covid-19", "boroughs")
select!(boroughs, Not(:recordedat))
mat_boroughs = convert(Matrix, boroughs)
# Out:
# 3×7 Array{Int64,2}:
#  41  17  26  95  46  48  84
#  14  17  12  41  26  28  63
#   6   5   4  19  12  14  41

# %%
plot(x=names(boroughs), y=mat_boroughs[end, :], Geom.bar, Theme(bar_spacing=10mm), Guide.xlabel("Boroughs"), Guide.ylabel("New infections"))
# Out:
# Plot(...)

# %% [markdown]
# Ok, let's see what else we can find out from our data.

# %% [markdown]
# ## I have questions
#
# Just diving into the data and start exploring a new dataset can be a lot of fun! Maybe you already have questions that can guide you in your exploration.
#
# Sometimes tho, we don't know yet exactly what questions we want to even ask. Where to start then?
#
# Well, one thing we can explore already, is the structure of the data. In this case, we have the development of the covid-19 pandemic as a time series, which opens up plenty of possible questions.

# %% [markdown]
# ### How are we doing?

# %%
function borough_plot(labels, values, theme)
    layer(x=labels, 
        y=values,
        Geom.bar,
        theme)
end
# Out:
# borough_plot (generic function with 1 method)

# %%
l1 = borough_plot(names(boroughs), mat_boroughs[1, :], Theme(default_color="orange", bar_spacing=10mm))
l2 = borough_plot(names(boroughs), mat_boroughs[2, :], Theme(default_color="red", bar_spacing=10mm))
l3 = borough_plot(names(boroughs), mat_boroughs[3, :], Theme(default_color="purple", bar_spacing=10mm))

plot(l3, l2, l1,        
    Guide.xlabel("Boroughs"),
    Guide.ylabel("New Infections"),
    Guide.title("New infections in the last 14 days"),
    Guide.manual_color_key("Time",["Now - 14 days ago", "7 - 21 days ago", "14 - 28 days ago"],["orange","red", "purple"]))
# Out:
# Plot(...)

# %%
df = dataset("covid-19", "infected")
df[1:10, :]
# Out:
# 10×7 DataFrame. Omitted printing of 2 columns
# │ Row │ deaths │ hospitalizations │ intensivecare │ new   │ recordedat │
# │     │ Int64? │ Int64?           │ Int64?        │ Int64 │ Date       │
# ├─────┼────────┼──────────────────┼───────────────┼───────┼────────────┤
# │ 1   │ 231    │ 19               │ 8             │ 58    │ 2020-08-11 │
# │ 2   │ 231    │ 19               │ 10            │ 13    │ 2020-08-10 │
# │ 3   │ 231    │ missing          │ missing       │ 14    │ 2020-08-09 │
# │ 4   │ 231    │ missing          │ missing       │ 54    │ 2020-08-08 │
# │ 5   │ 231    │ missing          │ missing       │ 80    │ 2020-08-07 │
# │ 6   │ 231    │ missing          │ missing       │ 44    │ 2020-08-06 │
# │ 7   │ 231    │ missing          │ missing       │ 25    │ 2020-08-05 │
# │ 8   │ 231    │ missing          │ missing       │ 17    │ 2020-08-04 │
# │ 9   │ 231    │ missing          │ missing       │ 8     │ 2020-08-03 │
# ...

# %%
function plotnewcases(df)
    layer(df, y=:new,x=:recordedat, Geom.bar)
end

plot(plotnewcases(df),
    Coord.cartesian(xmin=Date(2020, 3,1)),
    Guide.title("Confirmed new COVID-19 cases in Hamburg, Germany"), 
    Guide.xlabel("date"), 
    Guide.ylabel("new cases"))
# Out:
# Plot(...)

# %%
plot(plotnewcases(df[1:30, :]),
    Coord.cartesian(xmin=Date(2020, 7,1)),
    Guide.title("Confirmed new COVID-19 cases in Hamburg, Germany"), 
    Guide.xlabel("date"), 
    Guide.ylabel("new cases"))
# Out:
# Plot(...)

# %% [markdown]
# ### Early signs?

# %% [markdown]
# ### What's important?
#
# correlate

# %% [markdown]
# The first dataset shows the infections per borough, aggregated for 14 days. The aggregation happens to protect the privacy of the infected people.
#
# We did already plot the data when we build the webcrawler, so, let's spice it up a bit. We could over overlay the numbers from the two datapoints, to show the change in numbers over time.

# %% [markdown]
# ### Averaging for 7 days

# %% [markdown]
# ### Holidays

# %%
holidays = dataset("holidays", "school")
# Out:
# 9×3 DataFrame
# │ Row │ name                     │ start      │ end        │
# │     │ String                   │ Date       │ Date       │
# ├─────┼──────────────────────────┼────────────┼────────────┤
# │ 1   │ autumn holidays          │ 2019-10-09 │ 2019-10-18 │
# │ 2   │ reformation day holidays │ 2019-10-31 │ 2019-11-01 │
# │ 3   │ christmas holidays       │ 2019-12-20 │ 2020-01-03 │
# │ 4   │ mid year holidays        │ 2020-01-31 │ 2020-01-31 │
# │ 5   │ spring holidays          │ 2020-03-02 │ 2020-03-12 │
# │ 6   │ ascension holidays       │ 2020-05-18 │ 2020-05-22 │
# │ 7   │ summer holidays          │ 2020-06-25 │ 2020-08-05 │
# │ 8   │ autumn holidays          │ 2020-10-05 │ 2020-10-16 │
# │ 9   │ christmas holidays       │ 2020-12-21 │ 2021-01-04 │
